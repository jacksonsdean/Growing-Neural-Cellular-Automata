# %%
# %matplotlib inline
import time
import imageio

import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from IPython.display import clear_output

from lib.CAModel import CAModel
from lib.utils_vis import SamplePool, to_alpha, to_rgb, get_living_mask, make_seed, make_circle_masks

# %%
device = torch.device("cuda:0")
model_path = "models/to_text.pth"

CHANNEL_N = 16        # Number of CA state channels
TARGET_PADDING = 16   # Number of pixels used to pad the target image border
TARGET_SIZE = 40
# TARGET_SIZE = 120

lr = 2e-3
lr_gamma = 0.9999
betas = (0.5, 0.5)
n_epoch = 80000

BATCH_SIZE = 8
POOL_SIZE = 1024
CELL_FIRE_RATE = 0.5

TARGET_EMOJI = 0 #@param "🦎"

EXPERIMENT_TYPE = "Growing"
EXPERIMENT_MAP = {"Growing":0, "Persistent":1, "Regenerating":2}
EXPERIMENT_N = EXPERIMENT_MAP[EXPERIMENT_TYPE]

USE_PATTERN_POOL = [0, 1, 1][EXPERIMENT_N]
DAMAGE_N = [0, 0, 3][EXPERIMENT_N]  # Number of patterns to damage in a batch

USE_START_IMAGE = "../data/cradle.png"

# %%
def load_emoji(index, path="data/emoji.png"):
    im = imageio.imread(path)
    emoji = np.array(im[:, index*40:(index+1)*40].astype(np.float32))
    emoji /= 255.0
    return emoji



def visualize_batch(x0, x):
    vis0 = to_rgb(x0)
    vis1 = to_rgb(x)
    print('batch (before/after):')
    plt.figure(figsize=[15,5])
    for i in range(x0.shape[0]):
        plt.subplot(2,x0.shape[0],i+1)
        plt.imshow(vis0[i])
        plt.axis('off')
    for i in range(x0.shape[0]):
        plt.subplot(2,x0.shape[0],i+1+x0.shape[0])
        plt.imshow(vis1[i])
        plt.axis('off')
    plt.show()

def plot_loss(loss_log):
    plt.figure(figsize=(10, 4))
    plt.title('Loss history (log10)')
    plt.plot(np.log10(loss_log), '.', alpha=0.1)
    plt.show()

# %%
# target_img = load_emoji(TARGET_EMOJI)
# target_img = load_image("../data/cradle.png")
target_img = load_image("../data/grav0.png")
plt.figure(figsize=(4,4))
plt.imshow(to_rgb(target_img))
plt.show()
# Out:
# /users/j/s/jsdean/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   # This is added back by InteractiveShellApp.init_path()

# %%
p = TARGET_PADDING

pad_target = np.pad(target_img, [(p, p), (p, p), (0, 0)])

h, w = pad_target.shape[:2]
pad_target = np.expand_dims(pad_target, axis=0)
pad_target = torch.from_numpy(pad_target.astype(np.float32)).to(device)
if not USE_START_IMAGE:
    seed = make_seed((h, w), CHANNEL_N)
else:
    seed = np.zeros([h,w, CHANNEL_N], np.float32)
    seed_img = load_image(USE_START_IMAGE, resize_shape=(seed.shape[0], seed.shape[1]))
    seed[:, :, :4] = seed_img
pool = SamplePool(x=np.repeat(seed[None, ...], POOL_SIZE, 0))
batch = pool.sample(BATCH_SIZE).x

ca = CAModel(CHANNEL_N, CELL_FIRE_RATE, device).to(device)
# ca.load_state_dict(torch.load(model_path))

optimizer = optim.Adam(ca.parameters(), lr=lr, betas=betas)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, lr_gamma)
# Out:
# /users/j/s/jsdean/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   # This is added back by InteractiveShellApp.init_path()

# %%
loss_log = []

def train(x, target, steps, optimizer, scheduler):
    x = ca(x, steps=steps)
    loss = F.mse_loss(x[:, :, :, :4], target)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    scheduler.step()
    return x, loss

def loss_f(x, target):
    return torch.mean(torch.pow(x[..., :4]-target, 2), [-2,-3,-1])

for i in range(n_epoch+1):
    if USE_PATTERN_POOL:
        batch = pool.sample(BATCH_SIZE)
        x0 = torch.from_numpy(batch.x.astype(np.float32)).to(device)
        loss_rank = loss_f(x0, pad_target).detach().cpu().numpy().argsort()[::-1]
        x0 = batch.x[loss_rank]
        x0[:1] = seed
        if DAMAGE_N:
            damage = 1.0-make_circle_masks(DAMAGE_N, h, w)[..., None]
            x0[-DAMAGE_N:] *= damage
    else:
        x0 = np.repeat(seed[None, ...], BATCH_SIZE, 0)
    x0 = torch.from_numpy(x0.astype(np.float32)).to(device)
    x, loss = train(x0, pad_target, np.random.randint(64,96), optimizer, scheduler)
    
    if USE_PATTERN_POOL:
        batch.x[:] = x.detach().cpu().numpy()
        batch.commit()

    step_i = len(loss_log)
    loss_log.append(loss.item())
    
    if step_i%100 == 0:
        clear_output()
        print(step_i, "loss =", loss.item())
        visualize_batch(x0.detach().cpu().numpy(), x.detach().cpu().numpy())
        plot_loss(loss_log)
        torch.save(ca.state_dict(), model_path)
# Out:
# 35300 loss = 1.2399973456922453e-05
# batch (before/after):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_207986/413456484.py in <module>
#      38         clear_output()
#      39         print(step_i, "loss =", loss.item())
# ---> 40         visualize_batch(x0.detach().cpu().numpy(), x.detach().cpu().numpy())
#      41         plot_loss(loss_log)
#      42         torch.save(ca.state_dict(), model_path)
#
# /tmp/ipykernel_207986/2004482532.py in visualize_batch(x0, x)
#      17         plt.axis('off')
#      18     for i in range(x0.shape[0]):
# ---> 19         plt.subplot(2,x0.shape[0],i+1+x0.shape[0])
#      20         plt.imshow(vis1[i])
#      21         plt.axis('off')
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1302     else:
#    1303         # we have exhausted the known Axes and none match, make a new one!
# -> 1304         ax = fig.add_subplot(*args, **kwargs)
#    1305
#    1306     fig.sca(ax)
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     770             projection_class, pkw = self._process_projection_requirements(
#     771                 *args, **kwargs)
# --> 772             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773             key = (projection_class, pkw)
#     774         return self._add_axes_internal(ax, key)
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      32         """
#      33         # _axes_class is set in the subplot_class_factory
# ---> 34         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      35         # This will also update the axes position.
#      36         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     630
#     631         self._rasterization_zorder = None
# --> 632         self.cla()
#     633
#     634         # funcs used to format x and y - fall back on major formatters
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1248         self.containers = []
#    1249
# -> 1250         self.grid(False)  # Disable grid on init to use rcParameter
#    1251         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1252                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     300                 f"for the old name will be dropped %(removal)s.")
#     301             kwargs[new] = kwargs.pop(old)
# --> 302         return func(*args, **kwargs)
#     303
#     304     # wrapper() must keep the same documented signature as func(): if we
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3233         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3234         if axis in ['x', 'both']:
# -> 3235             self.xaxis.grid(visible, which=which, **kwargs)
#    3236         if axis in ['y', 'both']:
#    3237             self.yaxis.grid(visible, which=which, **kwargs)
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     300                 f"for the old name will be dropped %(removal)s.")
#     301             kwargs[new] = kwargs.pop(old)
# --> 302         return func(*args, **kwargs)
#     303
#     304     # wrapper() must keep the same documented signature as func(): if we
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1432             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1433                                 if visible is None else visible)
# -> 1434             self.set_tick_params(which='major', **gridkw)
#    1435         self.stale = True
#    1436
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     871             if which in ['major', 'both']:
#     872                 self._major_tick_kw.update(kwtrans)
# --> 873                 for tick in self.majorTicks:
#     874                     tick._apply_params(**kwtrans)
#     875             if which in ['minor', 'both']:
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     591                 instance.majorTicks = []
#     592                 tick = instance._get_tick(major=True)
# --> 593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#     595             else:
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     590             if self._major:
#     591                 instance.majorTicks = []
# --> 592                 tick = instance._get_tick(major=True)
#     593                 instance.majorTicks.append(tick)
#     594                 return instance.majorTicks
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2055         else:
#    2056             tick_kw = self._minor_tick_kw
# -> 2057         return XTick(self.axes, 0, major=major, **tick_kw)
#    2058
#    2059     def set_label_position(self, position):
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     413
#     414     def __init__(self, *args, **kwargs):
# --> 415         super().__init__(*args, **kwargs)
#     416         # x in data coords, y in axes coords
#     417         ax = self.axes
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/axis.py in __init__(self, axes, loc, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156             [], [],
#     157             color=color, linestyle="none", zorder=zorder, visible=tick2On,
# --> 158             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     159         )
#     160         self.gridline = mlines.Line2D(
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1053         """
#    1054         ret = []
# -> 1055         with cbook._setattr_cm(self, eventson=False):
#    1056             for k, v in props.items():
#    1057                 # Allow attributes we want to be able to update through
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/contextlib.py in helper(*args, **kwds)
#     237     @wraps(func)
#     238     def helper(*args, **kwds):
# --> 239         return _GeneratorContextManager(func, args, kwds)
#     240     return helper
#     241
#
# ~/scratch/bin/miniconda3/envs/torch/lib/python3.7/contextlib.py in __init__(self, func, args, kwds)
#      80
#      81     def __init__(self, func, args, kwds):
# ---> 82         self.gen = func(*args, **kwds)
#      83         self.func, self.args, self.kwds = func, args, kwds
#      84         # Issue 19330: ensure context manager instances have good docstrings
#
# KeyboardInterrupt:
